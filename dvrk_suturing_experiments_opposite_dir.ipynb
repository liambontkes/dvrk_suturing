# %%
# %load_ext autoreload
# %autoreload

# %%
import jupyros as jr
import rospy
import numpy as np
from sensor_msgs import msg
import cv2
import cv_bridge
from copy import deepcopy
import ipywidgets as widgets
import PIL.Image
from cStringIO import StringIO
import matplotlib.pyplot as plt
import dvrk
import PyKDL
import tf
import time
from tf_conversions import posemath
import utils

# %%
rospy.init_node('notebook')
rospy.get_published_topics()
# Out:
# [['/dvrk/setup_joint/robot_state', 'std_msgs/String'],
#  ['/dvrk/PSM1/current_state', 'std_msgs/String'],
#  ['/dvrk/ECM/wrench_body_current', 'geometry_msgs/WrenchStamped'],
#  ['/dvrk/PSM2/position_cartesian_local_current', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/console/teleop/teleop_psm_selected', 'diagnostic_msgs/KeyValue'],
#  ['/dvrk/PSM2/joint_velocity_ratio', 'std_msgs/Float64'],
#  ['/dvrk/ECM/state_joint_desired', 'sensor_msgs/JointState'],
#  ['/dvrk/console/teleop/teleop_psm_unselected', 'diagnostic_msgs/KeyValue'],
#  ['/dvrk/PSM2/position_cartesian_desired', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/ECM/position_cartesian_local_current', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/PSM1/status', 'std_msgs/String'],
#  ['/dvrk/PSM2/position_cartesian_current', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/tf_broadcast/period_statistics', 'cisst_msgs/mtsIntervalStatistics'],
#  ['/dvrk/PSM1/joint_velocity_ratio', 'std_msgs/Float64'],
#  ['/tf', 'tf2_msgs/TFMessage'],
#  ['/dvrk/PSM1/desired_state', 'std_msgs/String'],
#  ['/dvrk/ECM/position_cartesian_current', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/PSM1/position_cartesian_local_desired', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/PSM2/position_cartesian_local_desired', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/PSM1/wrench_body_current', 'geometry_msgs/WrenchStamped'],
#  ['/dvrk/PSM2/robot_state', 'std_msgs/String'],
#  ['/dvrk/PSM1/state_jaw_current', 'sensor_msgs/JointState'],
#  ['/dvrk/ECM/current_state', 'std_msgs/String'],
#  ['/dvrk/PSM1/jacobian_body', 'std_msgs/Float64MultiArray'],
#  ['/dvrk/ECM/joint_velocity_ratio', 'std_msgs/Float64'],
#  ['/dvrk/PSM2/current_state', 'std_msgs/String'],
#  ['/dvrk/PSM1/error', 'std_msgs/String'],
#  ['/dvrk/PSM1/twist_body_current', 'geometry_msgs/TwistStamped'],
#  ['/dvrk/PSM2/state_jaw_current', 'sensor_msgs/JointState'],
#  ['/dvrk/ECM/manip_clutch', 'sensor_msgs/Joy'],
#  ['/dvrk/PSM2/desired_state', 'std_msgs/String'],
#  ['/stereo/left/camera_info', 'sensor_msgs/CameraInfo'],
#  ['/dvrk/ECM/twist_body_current', 'geometry_msgs/TwistStamped'],
#  ['/dvrk/PSM2/manip_clutch', 'std_msgs/Bool'],
#  ['/dvrk/PSM2/error', 'std_msgs/String'],
#  ['/dvrk/ECM/position_cartesian_desired', 'geometry_msgs/PoseStamped'],
#  ['/stereo/right/camera_info', 'sensor_msgs/CameraInfo'],
#  ['/dvrk/PSM2/wrench_body_current', 'geometry_msgs/WrenchStamped'],
#  ['/stereo/left/image_raw', 'sensor_msgs/Image'],
#  ['/dvrk/PSM1/manip_clutch', 'std_msgs/Bool'],
#  ['/dvrk/PSM1/state_joint_desired', 'sensor_msgs/JointState'],
#  ['/dvrk/PSM1/position_cartesian_desired', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/PSM2/jacobian_spatial', 'std_msgs/Float64MultiArray'],
#  ['/dvrk/spin/period_statistics', 'cisst_msgs/mtsIntervalStatistics'],
#  ['/dvrk/ECM/state_joint_current', 'sensor_msgs/JointState'],
#  ['/rosout', 'rosgraph_msgs/Log'],
#  ['/dvrk/PSM2/warning', 'std_msgs/String'],
#  ['/dvrk/PSM2/goal_reached', 'std_msgs/Bool'],
#  ['/dvrk/PSM2/joint_acceleration_ratio', 'std_msgs/Float64'],
#  ['/dvrk/PSM2/jacobian_body', 'std_msgs/Float64MultiArray'],
#  ['/dvrk/PSM2/status', 'std_msgs/String'],
#  ['/dvrk/ECM/joint_acceleration_ratio', 'std_msgs/Float64'],
#  ['/dvrk/PSM2/state_joint_current', 'sensor_msgs/JointState'],
#  ['/dvrk/PSM2/state_jaw_current/sim', 'sensor_msgs/JointState'],
#  ['/dvrk/PSM1/goal_reached', 'std_msgs/Bool'],
#  ['/dvrk/PSM1/state_joint_current', 'sensor_msgs/JointState'],
#  ['/dvrk/PSM1/jacobian_spatial', 'std_msgs/Float64MultiArray'],
#  ['/rosout_agg', 'rosgraph_msgs/Log'],
#  ['/dvrk/PSM2/state_joint_desired', 'sensor_msgs/JointState'],
#  ['/dvrk/PSM1/joint_acceleration_ratio', 'std_msgs/Float64'],
#  ['/dvrk/PSM2/state_joint_current/sim', 'sensor_msgs/JointState'],
#  ['/dvrk/ECM/desired_state', 'std_msgs/String'],
#  ['/dvrk/PSM2/state_jaw_desired', 'sensor_msgs/JointState'],
#  ['/dvrk/PSM1/position_cartesian_local_current', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/ECM/warning', 'std_msgs/String'],
#  ['/dvrk/ECM/jacobian_spatial', 'std_msgs/Float64MultiArray'],
#  ['/dvrk/ECM/goal_reached', 'std_msgs/Bool'],
#  ['/dvrk/ECM/status', 'std_msgs/String'],
#  ['/dvrk/setup_joint/state_joint_current', 'sensor_msgs/JointState'],
#  ['/dvrk/publishers/period_statistics', 'cisst_msgs/mtsIntervalStatistics'],
#  ['/dvrk/PSM1/warning', 'std_msgs/String'],
#  ['/dvrk/ECM/error', 'std_msgs/String'],
#  ['/dvrk/PSM1/position_cartesian_current', 'geometry_msgs/PoseStamped'],
#  ['/stereo/right/image_raw', 'sensor_msgs/Image'],
#  ['/dvrk/ECM/position_cartesian_local_desired', 'geometry_msgs/PoseStamped'],
#  ['/dvrk/ECM/jacobian_body', 'std_msgs/Float64MultiArray'],
#  ['/dvrk/PSM1/state_jaw_desired', 'sensor_msgs/JointState'],
#  ['/dvrk/PSM2/twist_body_current', 'geometry_msgs/TwistStamped'],
#  ['/dvrk/console/teleop/scale', 'std_msgs/Float32']]

# %%
bridge = cv_bridge.CvBridge()
left_image = None
left_image_msg = None
left_camera_info = None

right_image = None
right_image_msg = None
right_camera_info = None

def left_image_callback(im_msg):
    global left_image, left_image_msg
    left_image = bridge.imgmsg_to_cv2(im_msg, desired_encoding='rgb8')
    left_image_msg = im_msg
    
def right_image_callback(im_msg):
    global right_image, right_image_msg
    right_image = bridge.imgmsg_to_cv2(im_msg, desired_encoding='rgb8')
    right_image_msg = im_msg
    
def left_camera_info_callback(camera_info_msg):
    global left_camera_info
    left_camera_info = camera_info_msg
    
def right_camera_info_callback(camera_info_msg):
    global right_camera_info
    right_camera_info = camera_info_msg
    
jr.subscribe('/stereo/left/image_raw', msg.Image, left_image_callback)
jr.subscribe('/stereo/left/camera_info', msg.CameraInfo, left_camera_info_callback)
jr.subscribe('/stereo/right/image_raw', msg.Image, right_image_callback)
jr.subscribe('/stereo/right/camera_info', msg.CameraInfo, right_camera_info_callback)

while left_image is None or right_image is None:
    print("left or right image not receieved")
    time.sleep(0.5)
# Out:
# left or right image not receieved

# %%
plt.imshow(np.hstack((left_image, right_image)))

# %%
tf_listener = tf.TransformListener()
time.sleep(1)
tf_listener.getFrameStrings()
# Out:
# /opt/ros/melodic/lib/python2.7/dist-packages/tf/listener.py:97: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(self._buffer.all_frames_as_yaml()) or {}
# ['ECM_RCM',
#  'PSM1_clip',
#  'ECM',
#  'PSM2_base',
#  'simcamera',
#  'PSM1_RCM',
#  'PSM1_base',
#  'PSM1',
#  'PSM2_RCM',
#  'PSM2',
#  'ECM_base',
#  'PSM2_clip']

# %%
psm1 = dvrk.psm('PSM1')
psm2 = dvrk.psm('PSM2')
ecm = dvrk.ecm('ECM')
while ecm.get_current_position() == PyKDL.Frame() or ecm.get_desired_position() == PyKDL.Frame():
    time.sleep(0.5)
while psm1.get_current_position() == PyKDL.Frame() or psm1.get_desired_position() == PyKDL.Frame():
    time.sleep(0.5)

# %%
# ECM_STARTING_JOINT_POS = np.asarray([-0.15669435,  0.17855662,  0.07069676,  0.17411496])
# ECM_STARTING_JOINT_POS = np.asarray([0.0615668 , 0.0523214 , 0.04854392, 0.15809197])
# ECM_STARTING_JOINT_POS = np.asarray([-0.14478268, -0.1293848 ,  0.00261061,  0.043541  ])
ECM_STARTING_JOINT_POS = np.asarray([0, -0.1 ,  0.05,  0.043541  ])
ecm.move_joint(ECM_STARTING_JOINT_POS)
# Out:
# True

# %%
time.sleep(1)
PSM_HOME_POS = np.asarray([0., 0., 0.05, 0., 0., 0.])
psm1.move_joint(PSM_HOME_POS)
psm1.close_jaw()

psm2.move_joint(PSM_HOME_POS)
psm2.close_jaw()
# Out:
# True

# %%
import image_geometry
utils = None
import utils
stereo_model = image_geometry.StereoCameraModel()
stereo_model.fromCameraInfo(left_camera_info, right_camera_info)

tf_cam_to_world = utils.tf_to_pykdl_frame(tf_listener.lookupTransform('simworld', 'simcamera', rospy.Time()))
tf_world_to_psm1 = \
    utils.tf_to_pykdl_frame(tf_listener.lookupTransform('PSM1_base', 'simworld', rospy.Time()))
tf_world_to_psm2 = \
    utils.tf_to_pykdl_frame(tf_listener.lookupTransform('PSM2_base', 'simworld', rospy.Time()))

objects, frame = utils.get_points_and_img(left_image_msg, right_image_msg, stereo_model, tf_cam_to_world)
plt.figure(figsize=(12, 5))
plt.imshow(frame)
for o in objects:
    o = PyKDL.Vector(o.x(), o.y(), o.z())
#     o = PyKDL.Vector(o.x(), o.y(), o.z())

# %%
len(objects)
# Out:
# 12

# %%
# pair up points that are across from each other
# x is *more or less* the axis along the wound
paired_pts = []
while objects:
    pt = objects[0]
    objects.remove(pt)
#     pt2 = min(objects, key=lambda obj : abs(obj.x() - pt.x()))
    pt2 = min(objects, key=lambda obj : abs(obj.y() - pt.y()))
    objects.remove(pt2)
#     paired_pts.append(
#         (max(pt, pt2, key=lambda p: p.y()), min(pt, pt2, key=lambda p: p.y())))
    paired_pts.append(
        (max(pt, pt2, key=lambda p: p.x()), min(pt, pt2, key=lambda p: p.x())))

z_val = paired_pts[0][0][2]
print(len(paired_pts)*2-1)
for i in range(len(paired_pts)):
    paired_pts[i][0][2] = z_val
    paired_pts[i][1][2] = z_val
    
print(paired_pts[0][0][1])
print(paired_pts[1][0][1])
paired_pts = sorted(paired_pts,key=lambda p: float(p[0][1]))
print("paired points sorted:")
paired_pts
# Out:
# 11
# 0.0361944867878
# 0.023959710212
# paired points sorted:
# [([    -1.51426,  -0.0277075,    0.647094],
#   [    -1.52992,  -0.0264462,    0.647094]),
#  ([    -1.51174,  -0.0132968,    0.647094],
#   [    -1.52602,  -0.0127484,    0.647094]),
#  ([    -1.50877, -0.00136464,    0.647094],
#   [    -1.52608,-0.000189877,    0.647094]),
#  ([    -1.51015,   0.0109381,    0.647094],
#   [    -1.52649,   0.0106897,    0.647094]),
#  ([    -1.51163,   0.0239597,    0.647094],
#   [    -1.52574,   0.0242937,    0.647094]),
#  ([    -1.51227,   0.0361945,    0.647094],
#   [    -1.52876,   0.0358238,    0.647094])]

# %%
import suturing_state_machine
reload(suturing_state_machine)
reload(utils)
import time

pts_psm1 = paired_pts[:3]
pts_psm2 = paired_pts[3:]
pts_psm2 = []

for sublist in (paired_pts[3:]):
    pts_psm2.append(sublist[::-1])
    
print("pts_psm1:", pts_psm1)
print("pts_psm1:", pts_psm2)

sm1 = suturing_state_machine.SuturingStateMachine(psm1, tf_world_to_psm1, pts_psm1, arm_name = 'PSM1')  
sm2 = suturing_state_machine.SuturingStateMachine(psm2, tf_world_to_psm2, pts_psm2, arm_name = 'PSM2')

start_time = time.clock()
while not sm1.is_done() or not sm2.is_done():
    sm1.run_once()
    sm2.run_once()
    time.sleep(0.1)
    
completion_time = time.clock() - start_time
print("completion time(s): ",completion_time)

# single PSM 
# pts_psm2 = paired_pts

# sm2 = suturing_state_machine.SuturingStateMachine(psm2, tf_world_to_psm2, pts_psm2, arm_name = 'PSM2')

# start_time = time.clock()
# while not sm2.is_done():
#     sm2.run_once()
#     time.sleep(0.1)
    
# completion_time = time.clock() - start_time
# print("completion time(s): ",completion_time)
# Out:
# ('pts_psm1:', [([    -1.51426,  -0.0277075,    0.647094], [    -1.52992,  -0.0264462,    0.647094]), ([    -1.51174,  -0.0132968,    0.647094], [    -1.52602,  -0.0127484,    0.647094]), ([    -1.50877, -0.00136464,    0.647094], [    -1.52608,-0.000189877,    0.647094])])
# ('pts_psm1:', [([    -1.51015,   0.0109381,    0.647094], [    -1.52649,   0.0106897,    0.647094]), ([    -1.51163,   0.0239597,    0.647094], [    -1.52574,   0.0242937,    0.647094]), ([    -1.51227,   0.0361945,    0.647094], [    -1.52876,   0.0358238,    0.647094])])
# [ERROR] [1602756153.143762]: bad callback: <bound method ecm.__state_joint_current_cb of <dvrk.ecm.ecm object at 0x7f1680233290>>
# Traceback (most recent call last):
#   File "/opt/ros/melodic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/home/parallels/dvrk_ws/src/dvrk-ros/dvrk_python/src/dvrk/arm.py", line 286, in __state_joint_current_cb
#     self.__effort_joint_current.resize(len(data.effort))
# ValueError: cannot resize an array that references or is referenced
# by another array in this way.
# Use the np.resize function or refcheck=False
# ('completion time(s): ', 59.113474)

# %%
dir(psm1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_arm__arm_current_state',
#  '_arm__arm_current_state_cb',
#  '_arm__arm_current_state_event',
#  '_arm__arm_desired_state',
#  '_arm__arm_desired_state_cb',
#  '_arm__arm_name',
#  '_arm__check_input_type',
#  '_arm__dmove_frame',
#  '_arm__dmove_rotation',
#  '_arm__dmove_translation',
#  '_arm__effort_joint_current',
#  '_arm__effort_joint_desired',
#  '_arm__full_ros_namespace',
#  '_arm__goal_reached',
#  '_arm__goal_reached_cb',
#  '_arm__goal_reached_event',
#  '_arm__init_arm',
#  '_arm__jacobian_body',
#  '_arm__jacobian_body_cb',
#  '_arm__jacobian_spatial',
#  '_arm__jacobian_spatial_cb',
#  '_arm__move_cartesian_direct',
#  '_arm__move_cartesian_goal',
#  '_arm__move_frame',
#  '_arm__move_joint',
#  '_arm__move_joint_direct',
#  '_arm__move_joint_goal',
#  '_arm__move_rotation',
#  '_arm__move_translation',
#  '_arm__position_cartesian_current',
#  '_arm__position_cartesian_current_cb',
#  '_arm__position_cartesian_desired',
#  '_arm__position_cartesian_desired_cb',
#  '_arm__position_cartesian_local_current',
#  '_arm__position_cartesian_local_current_cb',
#  '_arm__position_cartesian_local_desired',
#  '_arm__position_cartesian_local_desired_cb',
#  '_arm__position_joint_current',
#  '_arm__position_joint_desired',
#  '_arm__pub_list',
#  '_arm__ros_namespace',
#  '_arm__set_arm_desired_state_pub',
#  '_arm__set_desired_state',
#  '_arm__set_effort_joint_pub',
#  '_arm__set_gravity_compensation_pub',
#  '_arm__set_position_cartesian_pub',
#  '_arm__set_position_goal_cartesian_pub',
#  '_arm__set_position_goal_cartesian_publish_and_wait',
#  '_arm__set_position_goal_joint_pub',
#  '_arm__set_position_goal_joint_publish_and_wait',
#  '_arm__set_position_joint_pub',
#  '_arm__set_wrench_body_orientation_absolute_pub',
#  '_arm__set_wrench_body_pub',
#  '_arm__set_wrench_spatial_pub',
#  '_arm__state_joint_current_cb',
#  '_arm__state_joint_desired_cb',
#  '_arm__sub_list',
#  '_arm__twist_body_current',
#  '_arm__twist_body_current_cb',
#  '_arm__velocity_joint_current',
#  '_arm__wrench_body_current',
#  '_arm__wrench_body_current_cb',
#  '_psm__effort_jaw_current',
#  '_psm__effort_jaw_desired',
#  '_psm__position_jaw_current',
#  '_psm__position_jaw_desired',
#  '_psm__set_effort_jaw_pub',
#  '_psm__set_position_goal_jaw_pub',
#  '_psm__set_position_jaw_pub',
#  '_psm__set_tool_present_pub',
#  '_psm__state_jaw_current_cb',
#  '_psm__state_jaw_desired_cb',
#  '_psm__velocity_jaw_current',
#  'close_jaw',
#  'dinsert_tool',
#  'dmove',
#  'dmove_joint',
#  'dmove_joint_one',
#  'dmove_joint_some',
#  'get_arm_current_state',
#  'get_arm_desired_state',
#  'get_current_jaw_effort',
#  'get_current_jaw_position',
#  'get_current_jaw_velocity',
#  'get_current_joint_effort',
#  'get_current_joint_position',
#  'get_current_joint_velocity',
#  'get_current_position',
#  'get_current_position_local',
#  'get_current_twist_body',
#  'get_current_wrench_body',
#  'get_desired_jaw_effort',
#  'get_desired_jaw_position',
#  'get_desired_joint_effort',
#  'get_desired_joint_position',
#  'get_desired_position',
#  'get_desired_position_local',
#  'get_jacobian_body',
#  'get_jacobian_spatial',
#  'get_joint_number',
#  'home',
#  'insert_tool',
#  'move',
#  'move_jaw',
#  'move_joint',
#  'move_joint_one',
#  'move_joint_some',
#  'name',
#  'open_jaw',
#  'set_effort_jaw',
#  'set_effort_joint',
#  'set_gravity_compensation',
#  'set_tool_present',
#  'set_wrench_body_force',
#  'set_wrench_body_orientation_absolute',
#  'set_wrench_spatial_force',
#  'shutdown',
#  'unregister']

# %%
ecm.get_current_joint_position()
# Out:
# array([ 0.      , -0.1     ,  0.05    ,  0.043541])

# %%
psm2.close_jaw()
# Out:
# True
